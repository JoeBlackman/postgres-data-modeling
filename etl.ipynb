# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
import numpy as np
from datetime import datetime
from sql_queries import *
import create_tables

# %%
cur, conn = create_tables.create_database()
    
create_tables.drop_tables(cur, conn)
create_tables.create_tables(cur, conn)

conn.close()

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('data/song_data')

# %%
filepath = song_files[0]

# %%
song_data_df = pd.read_json(filepath, lines=True)
song_data_df.head()
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#   artist_name   duration  num_songs             song_id             title  \
# 0      Casual  218.93179          1  SOMZWCG12A8C13C480  I Didn't Mean To
#
#    year
# 0     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data_df[['song_id', 'title', 'artist_id', 'year', 'duration']]
# Out:
#               song_id             title           artist_id  year   duration
# 0  SOMZWCG12A8C13C480  I Didn't Mean To  ARD7TVE1187B99BFB1     0  218.93179

# %%
song_data = song_data_df[['song_id', 'title', 'artist_id', 'year', 'duration']].values[0].tolist()
print(song_data)
# Out:
# ['SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = song_data_df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].values[0].tolist()
print(artist_data)
# Out:
# ['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('data/log_data')

# %%
filepath = log_files[0]

# %%
log_data_df = pd.read_json(filepath, lines=True)
log_data_df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
log_data_df = log_data_df[log_data_df['page'] == 'NextSong']
log_data_df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %%
#log_data_df['ts'].apply(lambda x: datetime.fromtimestamp(x)) this isn't working

print(log_data_df['ts'].head())
t = pd.to_datetime(log_data_df['ts'], unit='ms')
#t = log_data_df['ts']
t.head()
# Out:
# 0    1543537327796
# 1    1543540121796
# 2    1543540368796
# 3    1543540625796
# 4    1543540856796
# Name: ts, dtype: int64
# 0   2018-11-30 00:22:07.796
# 1   2018-11-30 01:08:41.796
# 2   2018-11-30 01:12:48.796
# 3   2018-11-30 01:17:05.796
# 4   2018-11-30 01:20:56.796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = (t.astype(np.int64), t.dt.hour, t.dt.day, t.dt.week, t.dt.month, t.dt.year, t.dt.weekday)
column_labels = ('timestamp', 'hour', 'day', 'week', 'month', 'year', 'weekday')

# %%
time_df = pd.DataFrame.from_dict(dict(zip(column_labels, time_data)))
time_df.head()
# Out:
#              timestamp  hour  day  week  month  year  weekday
# 0  1543537327796000000     0   30    48     11  2018        4
# 1  1543540121796000000     1   30    48     11  2018        4
# 2  1543540368796000000     1   30    48     11  2018        4
# 3  1543540625796000000     1   30    48     11  2018        4
# 4  1543540856796000000     1   30    48     11  2018        4

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = log_data_df[['userId', 'firstName', 'lastName', 'gender', 'level']]

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
#need to examine why results is coming back as none every time
for index, row in log_data_df.iterrows():
    q = build_song_select_query(row.song, row.artist, row.length)
    cur.execute(q)
    print(q, results)
    #cur.execute(song_select, (row.song, row.artist, row.length))
    #results = cur.fetchone()
    #print(results)
# Out:
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Jim Henson's Dead$$ AND name=$$Stephen Lynch$$ AND duration=182.85669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Shell Shock$$ AND name=$$Manowar$$ AND duration=247.562);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Women Lose Weight (Feat: Slick Rick)$$ AND name=$$Morcheeba$$ AND duration=257.41016);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Won't Go Home Without You$$ AND name=$$Maroon 5$$ AND duration=231.23546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Hey_ Soul Sister$$ AND name=$$Train$$ AND duration=216.76363);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$I'm In Miami Bitch$$ AND name=$$LMFAO$$ AND duration=227.99628);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sexy Bitch$$ AND name=$$DJ Dizzy$$ AND duration=221.1522);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Cure & The Cause (Dennis Ferrer Remix)$$ AND name=$$Fish Go Deep & Tracey K$$ AND duration=377.41669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Staring At Me$$ AND name=$$M83$$ AND duration=96.1824);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Second You Sleep$$ AND name=$$Saybia$$ AND duration=257.25342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Wide Eyes$$ AND name=$$Local Natives$$ AND duration=266.05669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$La Resistance (Medley) (LP Version)$$ AND name=$$South Park$$ AND duration=112.97914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Restless$$ AND name=$$UNKLE Feat. Josh Homme$$ AND duration=307.19955);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Noc...$$ AND name=$$Justyna Steczkowska$$ AND duration=333.53098);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Like You$$ AND name=$$Evanescence$$ AND duration=256.91383);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$God Put A Smile Upon Your Face$$ AND name=$$Coldplay$$ AND duration=297.35138);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Playboy$$ AND name=$$Hot Chip$$ AND duration=333.50485);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Every Time You Go$$ AND name=$$Ellie Goulding$$ AND duration=205.06077);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Natural Anthem (Album)$$ AND name=$$Postal Service$$ AND duration=307.53914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Taylor$$ AND name=$$Jack Johnson$$ AND duration=240.06485);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Naked As We Can$$ AND name=$$Iron And Wine$$ AND duration=153.05098);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Fantasy$$ AND name=$$The xx$$ AND duration=158.24934);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Epilogue$$ AND name=$$The Antlers$$ AND duration=328.88118);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Groovin'$$ AND name=$$Fattburger$$ AND duration=217.20771);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Ain't No Way (You Won't Love Me)$$ AND name=$$Chris Brown$$ AND duration=203.80689);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Rome$$ AND name=$$Phoenix$$ AND duration=278.07302);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Highway Through My Home$$ AND name=$$Jim Lauderdale/Ralph Stanley & The Clinch Mountain Boys$$ AND duration=127.05914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$143$$ AND name=$$Musiq$$ AND duration=297.84771);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Dreams-Come-True-Girl$$ AND name=$$Cass McCombs feat. Karen Black$$ AND duration=322.06322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$I Don't Feel Like Dancin'$$ AND name=$$Scissor Sisters$$ AND duration=352.522);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Right On Time (Album Version)$$ AND name=$$O.A.R.$$ AND duration=315.74159);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Black Lines$$ AND name=$$1 Mile North$$ AND duration=352.73098);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Uprising$$ AND name=$$Muse$$ AND duration=304.84853);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Man Makes The Zoo$$ AND name=$$USS (Ubiquitous Synergy Seeker)$$ AND duration=307.61751);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Blacks/Radio$$ AND name=$$The Psychedelic Furs$$ AND duration=417.07057);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Love Dealer (Featuring Justin Timberlake)$$ AND name=$$EsmÃÂ©e Denters / Justin Timberlake$$ AND duration=227.52608);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$ReprÃÂ©sente$$ AND name=$$Alliance Ethnik$$ AND duration=252.21179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Hey_ Soul Sister$$ AND name=$$Train$$ AND duration=216.76363);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Up And Gone$$ AND name=$$Hoobastank$$ AND duration=202.57914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Te Conoci$$ AND name=$$Ismael Serrano$$ AND duration=179.35628);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Bottle Pop$$ AND name=$$The Pussycat Dolls / Snoop Dogg$$ AND duration=210.31138);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$My Love Will Follow You$$ AND name=$$Dierks Bentley$$ AND duration=198.63465);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Found Home$$ AND name=$$59 Times the Pain$$ AND duration=144.95302);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$My December$$ AND name=$$Linkin Park$$ AND duration=259.86567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Perfect Kiss$$ AND name=$$New Order$$ AND duration=288.05179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$You're Gonna Make Me Lonesome When You Go$$ AND name=$$Madeleine Peyroux$$ AND duration=206.18404);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Shortie Like Mine$$ AND name=$$Bow Wow feat. Chris Brown and JohntÃÂ¡ Austin$$ AND duration=268.06812);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Domination$$ AND name=$$Symphony X$$ AND duration=389.45914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Inside My Love (Digitally Remastered 93)$$ AND name=$$Minnie Riperton$$ AND duration=238.73261);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Structure$$ AND name=$$Custom Blue$$ AND duration=346.51383);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Killing In The Name$$ AND name=$$Rage Against The Machine$$ AND duration=314.40934);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Girl You Know It's True$$ AND name=$$Milli Vanilli$$ AND duration=197.92934);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Waterfall (Spirit Of The Rainforest Album Version)$$ AND name=$$David Arkenstone$$ AND duration=363.41506);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Robot Soul (Radio Edit)$$ AND name=$$Cosmo Vitelli$$ AND duration=206.05342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Blindfold$$ AND name=$$Morcheeba$$ AND duration=277.4722);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$I'm Yours (Album Version)$$ AND name=$$Jason Mraz$$ AND duration=243.48689);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Say Hello$$ AND name=$$Deep Dish$$ AND duration=274.28526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$(I Just) Died In Your Arms$$ AND name=$$Cutting Crew$$ AND duration=263.07873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sweet Jane$$ AND name=$$The Velvet Underground$$ AND duration=240.66567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Gears$$ AND name=$$Future Rock$$ AND duration=239.90812);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Seven Nation Army (Album Version)$$ AND name=$$The White Stripes$$ AND duration=231.81016);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Fix You$$ AND name=$$Coldplay$$ AND duration=294.1122);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$It Could Be Sweet$$ AND name=$$Portishead$$ AND duration=259.99628);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$If This Was The Last Song$$ AND name=$$Thelma Houston$$ AND duration=196.51873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Poppiholla$$ AND name=$$Chicane$$ AND duration=223.92118);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Unforgiven III$$ AND name=$$Metallica$$ AND duration=466.54649);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Apresurate$$ AND name=$$Jennifer Lopez$$ AND duration=301.34812);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$There Is$$ AND name=$$Box Car Racer$$ AND duration=196.93669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Would That Make U Love Me$$ AND name=$$Robin Thicke$$ AND duration=216.68526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Screaming Infidelities$$ AND name=$$Dashboard Confessional$$ AND duration=226.29832);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Big Idea$$ AND name=$$Radney Foster$$ AND duration=205.84444);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Bulletproof$$ AND name=$$La Roux$$ AND duration=205.60934);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Tune$$ AND name=$$Wax Tailor$$ AND duration=177.68444);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Trani$$ AND name=$$Kings Of Leon$$ AND duration=300.56444);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Girl Money$$ AND name=$$Kix$$ AND duration=246.25587);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Chloe Dancer/Crown Of Thorns$$ AND name=$$Mother Love Bone$$ AND duration=495.72526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Bachelor and the Bride$$ AND name=$$The Decemberists$$ AND duration=252.81261);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$M$$ AND name=$$Telefon Tel Aviv$$ AND duration=222.09261);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Nothin' On You [feat. Bruno Mars] (Album Version)$$ AND name=$$B.o.B$$ AND duration=269.63546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$You Sent Me Flying / Cherry$$ AND name=$$Amy Winehouse$$ AND duration=409.96526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Faithless$$ AND name=$$BEFORE THE DAWN$$ AND duration=195.65669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$You Only Live Once$$ AND name=$$The Strokes$$ AND duration=187.34975);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Tempting Time$$ AND name=$$Animals As Leaders$$ AND duration=323.83955);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Flowers In December$$ AND name=$$Mazzy Star$$ AND duration=297.9522);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Take It Back$$ AND name=$$Cream$$ AND duration=185.44281);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Behind Two Hills&A Swimming Pool$$ AND name=$$MÃÂºm$$ AND duration=68.67546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$My First Kiss (Feat. Ke$ha) [Album Version]$$ AND name=$$3OH!3$$ AND duration=192.522);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Straight Outta Compton (Extended Mix) (Edit) (Explicit)$$ AND name=$$N.W.A.$$ AND duration=266.26567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Goin' Home$$ AND name=$$Dan Auerbach$$ AND duration=296.95955);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sick$$ AND name=$$Lagwagon$$ AND duration=173.322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Fix You$$ AND name=$$Coldplay$$ AND duration=294.1122);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Half Of My Heart$$ AND name=$$John Mayer$$ AND duration=250.38322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Revelry$$ AND name=$$Kings Of Leon$$ AND duration=201.79546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$World Coming Down$$ AND name=$$Ashbury Heights$$ AND duration=198.60853);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Fire$$ AND name=$$Scooter$$ AND duration=213.02812);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Shoot Me Down$$ AND name=$$Boy Kill Boy$$ AND duration=220.47302);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Juice (Know The Ledge)$$ AND name=$$Eric B. & Rakim$$ AND duration=241.60608);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Hymne A L'Amour (Album Version)$$ AND name=$$Josh Groban$$ AND duration=243.40853);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$We're Only Gonna Die (Album Version)$$ AND name=$$Bad Religion$$ AND duration=131.86567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Next Hype$$ AND name=$$Tempa T$$ AND duration=236.35546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Fireflies$$ AND name=$$Charttraxx Karaoke$$ AND duration=225.17506);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Hotel California$$ AND name=$$Eagles$$ AND duration=372.29669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Little Wing$$ AND name=$$Eric Clapton$$ AND duration=409.57342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Smothered (Album Version)$$ AND name=$$Spineshank$$ AND duration=187.6371);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Try Your Best$$ AND name=$$Kaiser Chiefs$$ AND duration=221.07383);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Le Courage Des Oiseaux$$ AND name=$$Dominique A$$ AND duration=153.20771);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Lips Like Morphine (Album Version)$$ AND name=$$Kill Hannah$$ AND duration=224.49587);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Kiedys zrozumiesz$$ AND name=$$I:gor$$ AND duration=190.27546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Fallin' Apart$$ AND name=$$The All-American Rejects$$ AND duration=206.96771);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Don't Cry (Original)$$ AND name=$$Guns N' Roses$$ AND duration=284.05506);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Transparency$$ AND name=$$White Denim$$ AND duration=148.55791);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$La Suerte De Mi Vida$$ AND name=$$El Canto del Loco$$ AND duration=226.0371);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Redwing$$ AND name=$$Grinderswitch$$ AND duration=268.2771);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Starfish-On-The-Toast (2008 Digital Remaster)$$ AND name=$$Donovan$$ AND duration=169.22077);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Illusions$$ AND name=$$As I Lay Dying$$ AND duration=348.1073);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Bright Lights (Remastered Version)$$ AND name=$$matchbox twenty$$ AND duration=241.34485);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Field Goal$$ AND name=$$Kinky$$ AND duration=105.32526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Nah!$$ AND name=$$Shania Twain$$ AND duration=250.51383);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$By The Way$$ AND name=$$Hinder$$ AND duration=231.73179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Keep On Running$$ AND name=$$The Spencer Davis Group$$ AND duration=165.27628);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$I Dont Wanna Wait$$ AND name=$$SOJA$$ AND duration=355.89179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Echonomix$$ AND name=$$Infected Mushroom$$ AND duration=463.72526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$One By One$$ AND name=$$Unkle Bob$$ AND duration=160.10404);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sin Miedo a Nada (con Amaia Montero)$$ AND name=$$Alex Ubago$$ AND duration=313.28608);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Bonnie Brae$$ AND name=$$The Twilight Singers$$ AND duration=286.53669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$War$$ AND name=$$Chikita Violenta$$ AND duration=255.92118);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sad Lisa$$ AND name=$$Cat Stevens$$ AND duration=225.17506);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The House That Nat Built (Album Version)$$ AND name=$$Kenny Garrett$$ AND duration=265.19465);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Jealous Minds Think Alike$$ AND name=$$You Me At Six$$ AND duration=216.68526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$My Mother's Eyes$$ AND name=$$Nellie Lutcher$$ AND duration=195.70893);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Make Her Say$$ AND name=$$Kid Cudi / Kanye West / Common$$ AND duration=237.76608);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Viaje Sin Rumbo (2004 Digital Remaster)$$ AND name=$$Tiro De Gracia$$ AND duration=214.83057);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Dreamdancer$$ AND name=$$polarkreis 18$$ AND duration=265.29914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Queen of Nothing$$ AND name=$$+ / - {Plus/Minus}$$ AND duration=318.98077);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Riot In Cell Block Number Nine$$ AND name=$$Dr Feelgood$$ AND duration=216.13669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sehr kosmisch$$ AND name=$$Harmonia$$ AND duration=655.77751);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Everything You Love (Album Version)$$ AND name=$$Chimaira$$ AND duration=377.36444);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Someone Else's Life$$ AND name=$$Joshua Radin$$ AND duration=211.27791);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Godine prolaze$$ AND name=$$Bajaga & Instruktori$$ AND duration=254.95465);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Private Affair (Amended Album Version)$$ AND name=$$The Virgins$$ AND duration=169.37751);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Ginko Biloba$$ AND name=$$SA Rawls / Still Flyin' / Still Flyin'$$ AND duration=183.09179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Three Day Weekend$$ AND name=$$Grown Ups$$ AND duration=233.42975);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Meen Dah Elly Nseik$$ AND name=$$Nancy Ajram$$ AND duration=221.67465);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Boot On The Seat$$ AND name=$$The Donkeys$$ AND duration=272.19546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$FaFaFa (Radio Edit)$$ AND name=$$Datarock$$ AND duration=228.49261);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Human After All$$ AND name=$$Daft Punk$$ AND duration=319.42485);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Somebody To Love$$ AND name=$$Justin Bieber$$ AND duration=220.89098);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Real Love$$ AND name=$$Beach House$$ AND duration=320.44363);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Subterranean Homesick Blues (Album Version)$$ AND name=$$The Walkmen$$ AND duration=199.36608);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Can't Break Thru$$ AND name=$$Busted / Charlie Simpson / Mattie Jay / James Bourne$$ AND duration=252.83873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Get Me Bodied$$ AND name=$$BeyoncÃÂ©$$ AND duration=374.59546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Maybe$$ AND name=$$Sick Puppies$$ AND duration=209.44934);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Walk To The Water$$ AND name=$$U2$$ AND duration=289.2273);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$I CAN'T GET STARTED$$ AND name=$$Ron Carter$$ AND duration=497.13587);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Breath After Breath$$ AND name=$$Duran Duran$$ AND duration=297.63873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Head Over Heels$$ AND name=$$Tears For Fears$$ AND duration=255.34649);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Lonely As You$$ AND name=$$Foo Fighters$$ AND duration=277.10649);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$One Year_ Six Months$$ AND name=$$Yellowcard$$ AND duration=208.79628);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Against The Wall$$ AND name=$$Big Tymers$$ AND duration=252.05506);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Knocking On Forbidden Doors$$ AND name=$$Enigma$$ AND duration=262.71302);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Hey Hey$$ AND name=$$Dennis Ferrer$$ AND duration=209.162);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Somebody To Love$$ AND name=$$Justin Bieber$$ AND duration=220.89098);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Genom tunna tyger$$ AND name=$$Markus KrunegÃÂ¥rd$$ AND duration=185.5473);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Little Things Give You Away [Live At Milton Keynes]$$ AND name=$$Linkin Park$$ AND duration=439.562);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Devil May Care$$ AND name=$$Jamie Cullum$$ AND duration=204.25098);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Tell Me I'm A Wreck$$ AND name=$$Every Avenue$$ AND duration=219.95057);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Constellations$$ AND name=$$Jack Johnson$$ AND duration=201.63873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Vuelve$$ AND name=$$Shakira$$ AND duration=233.87383);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Give Me Anything$$ AND name=$$The Maine$$ AND duration=189.59628);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Worm Infested$$ AND name=$$Cannibal Corpse$$ AND duration=209.00526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Headlights Look Like Diamonds$$ AND name=$$Arcade Fire$$ AND duration=267.80689);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Hands Up$$ AND name=$$Black Eyed Peas$$ AND duration=215.7971);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sweet And Wild$$ AND name=$$Radney Foster$$ AND duration=288.96608);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Satellite Mind$$ AND name=$$Metric$$ AND duration=222.85016);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$You're The One$$ AND name=$$Dwight Yoakam$$ AND duration=239.3073);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Did You Get My Message? (Live From Montalvo)$$ AND name=$$Jason Mraz$$ AND duration=266.63138);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$N A Whitemanzeyez$$ AND name=$$Kutt Calhoun$$ AND duration=307.51302);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Karma Police$$ AND name=$$Radiohead$$ AND duration=261.45914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Puto$$ AND name=$$Molotov$$ AND duration=127.37261);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Killing Lies$$ AND name=$$The Strokes$$ AND duration=230.1122);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Hallelujah$$ AND name=$$Rufus Wainwright$$ AND duration=249.62567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Ghosts 'n' Stuff (Original Instrumental Mix)$$ AND name=$$Deadmau5$$ AND duration=374.20363);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$You're The Voice$$ AND name=$$John Farnham$$ AND duration=300.72118);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Inside Of You$$ AND name=$$Infant Sorrow$$ AND duration=170.16118);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Clean Up Woman (Single/LP Version)$$ AND name=$$Betty Wright$$ AND duration=164.85832);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Tranen Gelachen$$ AND name=$$Guus Meeuwis$$ AND duration=198.42567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Small Print$$ AND name=$$Muse$$ AND duration=209.00526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$A QuÃÂ© Niegas El Delirio (MalagueÃÂ±a) (Live)$$ AND name=$$Estrella Morente$$ AND duration=135.70567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$It's My Life (Radio Edit)$$ AND name=$$Dr. Alban$$ AND duration=240.14322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sit Down. Stand Up$$ AND name=$$Radiohead$$ AND duration=260.0224);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Purple Weed$$ AND name=$$Mondo Marcio$$ AND duration=263.60118);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Someone Else's Arms$$ AND name=$$Mae$$ AND duration=309.15873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Future Ain't What It Used To Be$$ AND name=$$Meat Loaf / Jennifer Hudson$$ AND duration=474.01751);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$A-Punk (Album)$$ AND name=$$Vampire Weekend$$ AND duration=137.82159);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Time To Pretend$$ AND name=$$MGMT$$ AND duration=264.17587);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Luna y Sol$$ AND name=$$Federico Aubele$$ AND duration=213.65506);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Touch My Horn$$ AND name=$$Jesse Rose$$ AND duration=313.15546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Eternity$$ AND name=$$Orion$$ AND duration=292.70159);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Dyed in the Wool (Album Version)$$ AND name=$$Circa Survive$$ AND duration=298.70975);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Wretchrospective (feat. Vis)$$ AND name=$$Wretch 32_ Vis$$ AND duration=243.35628);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Simple$$ AND name=$$Simian Mobile Disco$$ AND duration=354.61179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Riecht wie Teen Spirit (Smells Like Teen Spirit)$$ AND name=$$ErdmÃÂ¶bel$$ AND duration=289.25342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Adrenalin$$ AND name=$$Eisbrecher$$ AND duration=241.89342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Bread & Water$$ AND name=$$Ryan Bingham$$ AND duration=247.30077);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$VooDoo$$ AND name=$$Ashanti$$ AND duration=282.46159);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)$$ AND name=$$Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner$$ AND duration=277.15873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Frankie's Office$$ AND name=$$Clint Eastwood$$ AND duration=65.25342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Fireflies$$ AND name=$$Charttraxx Karaoke$$ AND duration=225.17506);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Summer Breeze$$ AND name=$$Jason Mraz$$ AND duration=264.69832);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Love Shack$$ AND name=$$The B-52's$$ AND duration=321.54077);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Alexandra$$ AND name=$$Aventura$$ AND duration=242.1024);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Canada$$ AND name=$$Five Iron Frenzy$$ AND duration=236.09424);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Anthem For The Underdog$$ AND name=$$12 Stones$$ AND duration=184.0322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Revelry$$ AND name=$$Kings Of Leon$$ AND duration=201.79546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Get Ready To Bounce Recall 08$$ AND name=$$Brooklyn Bounce$$ AND duration=359.13098);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Good Fight$$ AND name=$$Dashboard Confessional$$ AND duration=147.30404);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Low Land Moan$$ AND name=$$Lonnie Johnson$$ AND duration=194.55955);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$In$$ AND name=$$Leggo Beast$$ AND duration=376.58077);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sway$$ AND name=$$The Pussycat Dolls$$ AND duration=190.95465);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$I Miss You Now$$ AND name=$$Stereophonics$$ AND duration=290.53342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Masculine Eclipse$$ AND name=$$The Beautiful South$$ AND duration=236.5122);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$As If Set Afire$$ AND name=$$The Acacia Strain$$ AND duration=194.21995);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Underwater World$$ AND name=$$ATB$$ AND duration=251.48036);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Our Last Time$$ AND name=$$The Robert Cray Band$$ AND duration=309.52444);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$T.N.T. For The Brain (112 Bpm) (Radio Edit)$$ AND name=$$Enigma$$ AND duration=242.78159);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Tattered Banners And Bloody Flags$$ AND name=$$Amon Amarth$$ AND duration=268.2771);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Great Escape (Album Version) (Explicit)$$ AND name=$$We Are Scientists$$ AND duration=198.89587);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Lacreme napulitane$$ AND name=$$Roberto Murolo$$ AND duration=188.02893);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Autobiography$$ AND name=$$Ashlee Simpson$$ AND duration=214.43873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Ecstasy Of Gold$$ AND name=$$Metallica$$ AND duration=152.60689);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Kryptonite$$ AND name=$$3 Doors Down$$ AND duration=233.74322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$No Fool (For Love)$$ AND name=$$Hazell Dean$$ AND duration=367.98649);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Pray$$ AND name=$$Apocalyptica$$ AND duration=262.5824);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Bubble Toes$$ AND name=$$Jack Johnson$$ AND duration=236.93016);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Lotus$$ AND name=$$Cage The Elephant$$ AND duration=196.38812);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
# ...
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Lucky (Album Version)$$ AND name=$$Jason Mraz & Colbie Caillat$$ AND duration=189.6224);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Is She Weird$$ AND name=$$Pixies$$ AND duration=181.13261);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Without Me$$ AND name=$$Eminem$$ AND duration=251.55873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Cry No More$$ AND name=$$Buju Banton$$ AND duration=232.48934);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Lotus$$ AND name=$$Cage The Elephant$$ AND duration=196.38812);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)$$ AND name=$$Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner$$ AND duration=277.15873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Le Million$$ AND name=$$Ste Strausz$$ AND duration=285.36118);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Only Superstition$$ AND name=$$Coldplay$$ AND duration=228.62322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Bedroom Suite$$ AND name=$$Joe Christmas$$ AND duration=185.7824);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$A New Arrangement$$ AND name=$$Bright Eyes$$ AND duration=313.23383);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Only Exception (Album Version)$$ AND name=$$Paramore$$ AND duration=267.65016);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sinisten tÃÂ¤htien alla$$ AND name=$$J. Karjalainen & Mustat Lasit$$ AND duration=336.74404);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Knee 2$$ AND name=$$Philip Glass$$ AND duration=368.40444);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$SinceritÃÂ© Et Jalousie$$ AND name=$$Alliance Ethnik$$ AND duration=195.94404);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Her Voice Is Beyond Her Years$$ AND name=$$Mew$$ AND duration=167.75791);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$If You Leave Me Now$$ AND name=$$Ive Mendes$$ AND duration=238.94159);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$SinceritÃÂ© Et Jalousie$$ AND name=$$Alliance Ethnik$$ AND duration=195.94404);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Diamond Dave$$ AND name=$$the bird and the bee$$ AND duration=193.802);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$1999$$ AND name=$$Common / Sadat X$$ AND duration=256.20853);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$King Of Pain (Live/Unplugged Version)$$ AND name=$$Alanis Morissette$$ AND duration=245.15873);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Rebirthing (Album Version)$$ AND name=$$Skillet$$ AND duration=233.32526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Beauty and the Beast$$ AND name=$$James Galway;Julian Lee$$ AND duration=218.67057);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Dressed For Friend Requests (Album Version)$$ AND name=$$Drop Dead_ Gorgeous$$ AND duration=156.70812);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$You're The One$$ AND name=$$Dwight Yoakam$$ AND duration=239.3073);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Tuesday's Child$$ AND name=$$Trouble$$ AND duration=205.11302);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$All The Right Moves$$ AND name=$$OneRepublic$$ AND duration=237.97506);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Wicked$$ AND name=$$Switchblade Symphony$$ AND duration=259.5522);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$My Distressor 40Khz ReRub Mix$$ AND name=$$Sharooz$$ AND duration=234.05669);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Six Days At The Bottom Of The Ocean$$ AND name=$$Explosions In The Sky$$ AND duration=522.9971);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Little Bird$$ AND name=$$Emmylou Harris$$ AND duration=194.63791);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Horizon Has Been Defeated$$ AND name=$$Jack Johnson$$ AND duration=153.67791);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Everything In Its Right Place$$ AND name=$$Radiohead$$ AND duration=249.93914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Heretics$$ AND name=$$Andrew Bird$$ AND duration=215.87546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sabbra Cadabra$$ AND name=$$Metallica$$ AND duration=380.21179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Catch You Baby (Steve Pitron & Max Sanna Radio Edit)$$ AND name=$$Lonnie Gordon$$ AND duration=181.21098);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Shattered$$ AND name=$$Dropkick Murphys$$ AND duration=167.73179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$As The Rhyme Goes On$$ AND name=$$Eric B. & Rakim$$ AND duration=240.32608);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Settle For A Slowdown$$ AND name=$$Dierks Bentley$$ AND duration=223.242);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Daniel Cowman$$ AND name=$$Regina Spektor$$ AND duration=290.14159);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Make You Sin$$ AND name=$$Angelspit$$ AND duration=241.94567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Roc U$$ AND name=$$Young Gunz / Beanie Sigel$$ AND duration=292.44036);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sexy Bitch$$ AND name=$$DJ Dizzy$$ AND duration=221.1522);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sayonara-Nostalgia$$ AND name=$$Base Ball Bear$$ AND duration=255.60771);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$In The Hands Of The Gods (Featuring Biz Markie)$$ AND name=$$Morcheeba$$ AND duration=101.95546);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Don't Forget To Breathe$$ AND name=$$Bitter:Sweet$$ AND duration=194.16771);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Now You're Gone$$ AND name=$$Basshunter Feat. DJ Mental Theos Bazzheadz$$ AND duration=152.65914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Undo$$ AND name=$$BjÃÂ¶rk$$ AND duration=348.57751);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$G4L$$ AND name=$$Rihanna$$ AND duration=239.75138);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Hello$$ AND name=$$Evanescence$$ AND duration=220.3424);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Tamale$$ AND name=$$Mr. Vegas$$ AND duration=240.69179);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Another Place$$ AND name=$$Mischa Daniels$$ AND duration=419.81342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Straight To Hell$$ AND name=$$The Menzingers$$ AND duration=276.00934);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Cry Me A River$$ AND name=$$Justin Timberlake$$ AND duration=288.93995);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Un Camino Hasta Vos$$ AND name=$$Vilma Palma e Vampiros$$ AND duration=338.18077);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Sura (2008 Digital Remaster)$$ AND name=$$CCCP - Fedeli Alla Linea$$ AND duration=329.66485);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Pursuit Of Happiness (nightmare)$$ AND name=$$Kid Cudi / MGMT / Ratatat$$ AND duration=295.67955);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Forever$$ AND name=$$Drake / Kanye West / Lil Wayne / Eminem$$ AND duration=357.66812);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Homesick [Acoustic]$$ AND name=$$A Day To Remember$$ AND duration=247.64036);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)$$ AND name=$$T.I.$$ AND duration=299.75465);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$It'll Be a Long Time (Album Version)$$ AND name=$$The Offspring$$ AND duration=163.3171);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Esta Es Para Hacerte FÃÂ©liz$$ AND name=$$Jorge Gonzalez$$ AND duration=272.14322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Spin Spin Sugar$$ AND name=$$Sneaker Pimps$$ AND duration=260.91057);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$This War Is Ours (The Guillotine II)$$ AND name=$$Escape The Fate$$ AND duration=266.73587);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$La Vida Es Un Ratico$$ AND name=$$Juanes$$ AND duration=243.27791);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Never Mind$$ AND name=$$The Replacements$$ AND duration=170.57914);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Possession$$ AND name=$$Sarah McLachlan$$ AND duration=278.90893);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Don't Start Me Talkin'$$ AND name=$$Sonny Boy Williamson$$ AND duration=152.24118);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler)$$ AND name=$$Soul II Soul Featuring Caron Wheeler$$ AND duration=225.2273);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Dog Days Are Over (Radio Edit)$$ AND name=$$Florence + The Machine$$ AND duration=219.66322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Heresy  (LP Version)$$ AND name=$$Pantera$$ AND duration=286.69342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Remedy$$ AND name=$$Cold$$ AND duration=177.76281);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Frozen Angel$$ AND name=$$Norther$$ AND duration=246.54322);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Pretender$$ AND name=$$Foo Fighters$$ AND duration=271.38567);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Besos De Ceniza$$ AND name=$$Timbiriche$$ AND duration=202.60526);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Rose$$ AND name=$$A Perfect Circle$$ AND duration=206.05342);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$The Haunting$$ AND name=$$Anberlin$$ AND duration=348.682);
#      None
#
#     SELECT song_id, song.artist_id
#     FROM song
#     JOIN artist ON song.artist_id=artist.artist_id
#     WHERE (title=$$Anything You Say (Unreleased Version)$$ AND name=$$Deas Vail$$ AND duration=237.68771);
#      None

# %%
for index, row in log_data_df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (index, row.ts, row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %%
s = cur.execute("""SELECT * FROM song_play;""")
conn.commit()
print(s)

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
